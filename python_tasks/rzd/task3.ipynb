# %%
import datetime
import os
import random
f=open('id.txt','a+')
for line in f:
    if line=='-1'+'\n' or line=='-1':
        break
    else:
        f.write('-1'+'\n')
f.close()

def right_now_timer(right_now_min,right_now_hour):
    right_now_time=str(right_now_hour)+':'+str(right_now_min)
    return right_now_time
def datamaker(right_now_year,right_now_month,right_now_day):
    right_now_data=str(right_now_day)+'.'+str(right_now_month)+'.'+str(right_now_year)
    return right_now_data
def datazero(data):
    data='0'+str(data)
    return data
def tickets(surname,name,patronymic,age,take,end,t1,t2,right_now_data,fly_data,case,idi):
    lenn=0
    data='Персональные данные: '+surname+'|'+name+'|'+patronymic+'|'+age+'|'
    info='Место в самолете '+take+'\n'+'Время в пути: '+str(timer(end))+'\n'+'Время вылета: '+t1+' '+'Время прилета: '+t2+'\n'
    k='Дата покупки: '+right_now_data+' '+'Дата полета: '+fly_data+'\n'
    way='Маршрут: '+case
    idii='Ваш номер билета: '+str(idi)
    if len(data)>lenn:
        lenn=len(data)
    if len(info)>lenn:
        lenn=len(info)
    if len(k)>lenn:
        lenn=len(k)
    if len(way)>lenn:
        lenn=len(way)
    if len(idii)>lenn:
        lenn=len(idii)
    visio='-'*lenn
    print(visio)
    print(data)
    print(info)
    print(k)
    print(way)
    print(idii)
    print(visio)
def id_number(idi):
    f=open('id.txt','r')
    idi=-1
    for line in f:
        if line.isspace()==False:
            
            idi+=1
    f.close()
    f=open('id.txt','a')
    f.write('\n'+str(idi)+'\n')
    f.close()
   
    return idi
        
        
dictionary={}
dic={}
okeykeys=0
right_now = datetime.datetime.now()
right_now_year=right_now.year
right_now_month=right_now.month
right_now_day=right_now.day
right_now_hour=right_now.hour
right_now_min=right_now.minute
right_now_time=right_now_timer(right_now_min,right_now_hour)
right_now_data=datamaker(right_now_year,right_now_month,right_now_day)

some_variable=True
with open("info.txt") as file:
    for line in file:
        key, *value = line.split()
        dictionary[key] = value

ask=input('Приветствуем в нашей авиакомпании "Mdashan"! Хотите купить билет или сдать?("buy","pass")')

if ask=='buy':
    
    print('Список рейсов: ')
    for i,j in dictionary.items():
        print(i,j)
    print('Наша авиакомпания очень любит путешествия, поэтому любой самолет летает каждый день по данному расписанию.')
    print('Выберите дату поездки.')
    fly_year=right_now_year
    fly_month=input('Введите месяц(11 или 12, к примеру)')
    fly_day=input('Введите день(03,02,01 или 11,к примеру)')
    while True:
    
        while True:
            if fly_month.isdigit()!=True or int(fly_month)>12 or int(fly_month)<1 or int(fly_month)<right_now_month or len(fly_month)>2:
                fly_month=input('Введите нормальное число месяца.')
            else:
                break


        while True:

            if fly_day.isdigit()!=True or len(fly_day)>2 or int(fly_day)>31 or int(fly_day)<1 or (int(fly_day)<int(right_now_day) and int(fly_month)==int(right_now_month)):
                 fly_day=input('Введите нормальное число.')
            else:
                break
        while True:
            if (int(fly_month)==11 and int(fly_day)==31) or fly_day.isdigit()!=True or len(fly_day)>2 or int(fly_day)>31 or \
            int(fly_day)<1 or (int(fly_day)<int(right_now_day) and int(fly_month)==int(right_now_month)) or fly_month.isdigit()!=True or int(fly_month)>12 or int(fly_month)<1 or int(fly_month)<right_now_month or len(fly_month)>2:
                print('Такой даты не существует')
                fly_month=input('Введите нормальное число месяца.')
                fly_day=input('Введите нормальное число дня.')
            else:
                break
        break
        
        
    print('Отлично!')
    if len(fly_day)==1:
        fly_day=datazero(fly_day)
    if len(fly_month)==1:
        fly_month=datazero(fly_month)    
    
    fly_data=datamaker(fly_year,fly_month,fly_day)
    print(fly_data)
    print(right_now_data)
    if fly_data==right_now_data:
        okeykeys=1
    
            
    case0, case1, case2, case3, case4 = '', '', '', '',''
    time0,time1, time2, time3, time4 = [], [], [], [], []
    a, b, c, d, e = '', '', '', '', ''
    k = 0
    start = str(input('Откуда вы хотите попасть: ')).upper()
    stop = str(input('Куда вы хотите попасть: ')).upper()
    def places():
        global place
        place={}
        place[1]=None
        place[2]=None
        place[3]=None
        place[4]=None
        place[5]=None
        place[6]=None
        place[7]=None
        return place

    def timer(time):
        hh = time // 60
        mm = time % 60
        if len(str(hh)) == 1:
            hh = '0' + str(hh)
        if len(str(mm)) == 1:
            mm = '0' + str(mm)
        time = str(hh) + ':' + str(mm)
        return time


    def amount_time(start, end):
        massiv = []

        end = end.split(':')
        start = start.split(':')
        end = [int(i) for i in end]
        start = [int(i) for i in start]
        if end[0] == 0:
            end[0] = 24
        if end[1] >= start[1] and end[0] >= start[0]:
            massiv.append(end[0] - start[0])
            massiv.append(end[1] - start[1])
        elif end[1] < start[1]:
            end[0] -= 1
            end[1] += 60
            if end[0] >= start[0]:
                massiv.append(end[0] - start[0])
                massiv.append(end[1] - start[1])
            else:
                massiv.append(end[0] - start[0] + 24)
                massiv.append(end[1] - start[1])
        else:
            massiv.append(end[0] - start[0] + 24)
            massiv.append(end[1] - start[1])
        massiv = [str(i) for i in massiv]

        time = ':'.join(massiv)

        return time
    def to_normal(time):
        time2 = []
        for i in time:

            i = i.split(':')
            i = int(i[0]) * 60 + int(i[1])
            time2.append(i)
        return sum(time2)




    for k0, i0 in dictionary.items():
        if i0[0] == start and i0[2] != stop:
            a = i0[2]
            for k1, i1 in dictionary.items(): #1 пересадка
                if k1 != k0:
                    b = i1[2]
                    if i1[0] == a and i1[2] == stop:
                        k += 1
                        case1 = (start + '->>(' + k0 + ')->>' + a + '->>(' + k1 +
                                   ')->>' + b)
                        time1 = [
                            amount_time(i0[1], i0[3]), amount_time(i0[3], i1[1]),
                            amount_time(i1[1], i1[3])
                        ]
                        time1 = to_normal(time1)
                       

                    elif i1[0] == a and i1[2] != stop:
                        for k2, i2 in dictionary.items():
                            if k2 != k0 != k1:
                                c = i2[2]
                                if i2[0] == b and i2[2] == stop:
                                    k += 1
                                    case2 = (start + '->>(' + k0 + ')->>' + a + '->>(' +
                                             k1 + ')->>' + b + '->>(' + k2 + ')->>' + c)
                                    time2 = [
                                        amount_time(i0[1], i0[3]), amount_time(i0[3], i1[1]),
                                        amount_time(i1[1], i1[3]), amount_time(i1[3], i2[1]),
                                        amount_time(i2[1], i2[3])
                                    ]
                                    time2 = to_normal(time2)
                                    
                                    
                                    
                                elif i2[0] == b and i2[2] != stop:
                                    for k3, i3 in dictionary.items():
                                        if k3 != k2 != k0 != k1:
                                            d = i3[2]
                                            if i3[0] == c and i3[2] == stop:
                                                k += 1
                                                case3 = (start + '->>(' + k0 + ')->>' + a +
                                                           '->>(' + k1 + ')->>' + b + '->>(' +
                                                         k2 + ')->>' + c + '->>(' + k3 +
                                                           ')->>' + d)
                                                time3 = [
                                                    amount_time(i0[1], i0[3]), amount_time(i0[3], i1[1]),
                                                    amount_time(i1[1], i1[3]), amount_time(i1[3], i2[1]),
                                                    amount_time(i2[1], i2[3]), amount_time(i2[3], i3[1]),
                                                    amount_time(i3[1], i3[3])
                                                ]
                                                time3 = to_normal(time3)
                                                
                                                
                                            elif i3[0] == c and i3[2] != stop:
                                                for k4, i4 in dictionary.items():
                                                    if k4 != k3 != k2 != k0 != k1:
                                                        e = i4[2]
                                                        if i4[0] == d and i4[2] == stop:
                                                            k += 1
                                                            case4 = (start + '->>(' + k0 +
                                                                       ')->>' + a + '->>(' + k1 +
                                                                       ')->>' + b + '->>(' + k2 +
                                                                       ')->>' + c + '->>(' + k3 +
                                                                       ')->>' + d + '->>(' + k4 +
                                                                       ')->>' + e)
                                                            time4 = [
                                                                amount_time(i0[1], i0[3]),
                                                                amount_time(i0[3], i1[1]),
                                                                amount_time(i1[1], i1[3]),
                                                                amount_time(i1[3], i2[1]),
                                                                amount_time(i2[1], i2[3]),
                                                                amount_time(i2[3], i3[1]),
                                                                amount_time(i3[1], i3[3]),
                                                                amount_time(i3[3], i4[1]),
                                                                amount_time(i4[1], i4[3])
                                                            ]
                                                            time4 = to_normal(time4)
        if i0[0]==start and i0[2]==stop:
            
            time0=[amount_time(i0[1], i0[3])]
            time0=to_normal(time0)
            k=1
            case0 = (start + '->>('+k0+')->>' +stop)
            
            
    if k == 0:

        print('Рейс не найден.')
    else:
        
        time_sort = [time0,time1, time2, time3, time4]
        #очищаем от пустых список
        time_sort = [i for i in time_sort if i != []]
        end = min(time_sort)
        
        if end == time1:
            print(' Время в пути:', timer(time1), '\n', 'Маршрут:', case1)
            price=time1*10
            case=case1
        elif end == time2:
            print(' Время в пути:', timer(time2), '\n', 'Маршрут:', case2)
            price=time2*10
            case=case2
        elif end == time3:
            print(' Время в пути:', timer(time3), '\n', 'Маршрут:', case3)
            price=time3*10
            case=case3
        elif end == time4:
            price=time4*10
            case=case4
            print(' Время в пути:', timer(time4), '\n', 'Маршрут:', case4)
        elif end==time0:
            price=time0*10
            case=case0
            print('Время в пути:',timer(time0), '\n','Маршрут:',case0)
            print('Данный рейс будет без пересадок.')
        
        for i in range(len(case)-1):
            if case[i]=="(":
                remi=i
                break
        
        for i in range(remi+1,len(case)):
            if case[i].isdigit()==True:
                
                remii=i
            else:
                break
        
        travel1=case[remi+1:remii+1]
        
        for i,j in dictionary.items():
            if i==travel1:
                
                t1=j[1]
                break
        
        
        for i in range(len(case)-1,-1,-1):
            if case[i]==')':
                remi=i
                break
        for i in range(remi-1,-1,-1):
            if case[i].isdigit()==True:
                   remii=i
            else:
                break
        travel2=case[remii:remi]
        for i,j in dictionary.items():
            if i==travel2:
                
                t2=j[3]
                break 
        if travel1==travel2:
            for i,j in dictionary.items():
                if i==travel1:
                    t2=j[3]
                    break
        
        hah=0
        if okeykeys==1 and right_now_time>=t1:
            print('К сожалению, вы опоздали на рейс.')
            hah=1
        if hah==0:   
            print('Цена данного билета: '+str(price))
            print('Вы готовы совершить покупку? YES or NO')
            pr=str(input()).upper()
            if pr=='YES':
                ff=open("service.txt","r")
                for line in ff:

                    if  fly_data+case!= line and fly_data+case+'\n'!= line: #тут тоже дату
                        some_variable = True
                    else:  
                        some_variable = False
                        break
                ff.close()
                ff=open('service.txt','a')
                if  some_variable== True:
                    places()
                    ff.write(fly_data+case+'\n') #тут дату еще
                    for i,j in place.items():
                        ff.write(str(i)+' '+str(j)+'\n')





                   #если уже есть данный рейс 
                ff.close()
                ff=open('service.txt','r')
                cou1=0
                cou2=0
                cou3=0
                cou4=0
                ss=0
                for line in ff:
                    ss+=1
                ff.close()
                ff=open('service.txt','r')
                for line in ff:
                    cou1+=1
                    if line==fly_data+case or line==fly_data+case+'\n': #добавляем дату
                        indexline1=cou1
                        break
                ff.close()

                ff=open('service.txt','r')

                for line1 in ff:

                         cou2+=1

                         if cou2==ss:
                            indexline2=cou2+1
                            break
                         if line1!=fly_data+case and line1!=fly_data+case+'\n' and line1.find('->>')!=-1 and cou2>indexline1: #дату

                                indexline2=cou2
                                break


                
                ff.close()
                ff=open('service.txt','r')

                for line in ff:
                    cou3+=1
                    if cou3==indexline1+1:
                        ff.close()
                        cou3==indexline1+1
                        break
                
                ff=open('service.txt','r')
                for line1 in ff:
                            cou4+=1
                            if cou4==indexline2:
                                 break
                            if cou4>=cou3:

                                keys, *values = line1.split()
                                dic[keys] = values


                ff.close()
                diccopy={}
                seating=0
                print('Информация о местах:')
                for i,j in dic.items():

                    if j==['None']:
                        diccopy[i]=j
                        print(i,j)
                        seating=1
                if seating==1:
                    
                    print('Так какое место выбираете? Напишите просто цифру.')
                    take=input()

                    while True:
                        if take not in diccopy.keys():
                          take=input('Попробуйте ввести корректно.')
                        else:
                            break
                    print('Отлично! Теперь нам нужны ваши данные.')
                    surname=input('Введите вашу фамилию на английском')
                    name=input('Введите ваше имя на английском.')
                    patronymic=input('Введите ваше отчество на английском')
                    age=input('Введите ваш возраст')
                    print('Отлично! Мы получили ваши данные. Сейчас будем создавать билет...')
                    f=open('service.txt','r')
                    ff=open('service1.txt','w+')
                    r=0
                    r1=0
                    for line in f:
                        r+=1
                        r1+=1
                        if r>=indexline1+1 and r<indexline2:
                            if line[0]==take:
                                indexlinemesto=r
                                line=line.replace('None',surname+' '+name+' '+patronymic)
                        else:
                            r1-=1
                                
                        ff.write(line)
                    f.close()
                    ff.close()
                    f=open('service.txt','w')
                    ff=open('service1.txt','r')
                    for line in ff:
                            f.write(line)
                    f.close()
                    ff.close()
                    
                    os.remove('service1.txt') #тут была перезапись файла с учетом занятого места
                    idi=-1
                    idi=id_number(idi)
                    
                    ticket=str(idi)+'|'+surname+'|'+name+'|'+patronymic+'|'+age+'|'+str(take)+'|'+str(price)+'|'+str(timer(end))+'|'
                    ticket+=str(t1)+'|'+str(t2)+'|'+str(fly_data)+'|'+str(right_now_data)+'|'+case+'|'+str(indexlinemesto)+'\n'
                    
                    f=open('tickets.txt','a+')
                    f.write(ticket)
                    f.close()
                    print('Ваш билет готов! Хорошей поездки!')
                    tickets(surname,name,patronymic,age,take,end,t1,t2,right_now_data,fly_data,case,idi)
                    
                    
                    
                            
                    
                    
                else:
                    print('К сожалению, все места на эту дату заняты. Покупка была отменена.')
            
            
                
            
                    
            else:
                print('Покупка была отменена.')
        
elif ask=="pass":
    
    print('Сейчас мы будем осуществлять вам возврат. Ознакомьтесь с политикой возврата:')
    print('Если ваш возврат производится до дня отлета(не в день отлета!), то стоимость возвращается та же.')
    print('Если вы отдаете в день отлета(до отлета), то вы теряете 35%')
    print('В противном случае возврат невозможен.')
    reserve=input('Введите номер вашего билета.')
    f=open('tickets.txt','r')
    jj=-1
    code=0
    for line in f:
        for i in range(len(line)-1):
            if line[i]=='|':
                jj=i
                break
                
        
        if line[0:jj]==reserve:
                   code=1
                   
                   
        
           
    f.close()
    linerid=-1
    linerid1=-1
    linerid2=-1
    linerid3=-1
    linerid4=-1
    liner=0
    liner1=0
    liner2=0
    linerid5=-1
    linerdid6=-1
    if code==1:
        f=open('tickets.txt','r')
        for line in f:
         
         if line[0:jj]==reserve:
            for i in range(len(line)-1):
                if line[i]=='|':
                    liner+=1
                if liner==10:
                    linerid=i
                    break
            
            for i in range(linerid+1,len(line)):
                if line[i]=='.':
                    linerid1=i
                    
                if linerid1!=-1: #точка между днем и месяцем
                    break
            for i in range(linerid1+1,len(line)):
                if line[i]=='.':
                    linerid2=i
                if linerid2!=-1: #перед годом
                    break
            
            way_month=line[linerid1+1:linerid2]
            way_day=line[linerid+1:linerid1]
            
            for i in range(len(line)-1):
                if line[i]=='|':
                    liner1+=1
                    if liner1==8:
                        linerid3=i
                    if liner1==9:
                        linerid4=i
                        break
            for i in range(len(line)-1):
                if line[i]=='|':
                    liner2+=1
                    if liner2==6:
                        linerid5=i
                    if liner2==7:
                        linerid6=i
                        break
           
            way_price=line[linerid5+1:linerid6]
            
            
            way_hour=line[linerid3+1:linerid4]
            break
        f.close()
        liner3=0
        linerid7=-1
        if int(right_now_month)<int(way_month):
            print('Цена вашего билета:'+str(way_price))
            print('Происходит возврат средств...')
            
           
            print('На ваш счет были зачислены '+str(way_price))
            f=open('tickets.txt','r')
            for line in f:
              if line[0:jj]==reserve:
                for i in range(len(line)-1):
                    if line[i]=='|':
                        liner3+=1
                        if liner3==13:
                            linerid7=i
                            break
                break
            f.close()
            
            f=open('tickets.txt','r')
            for line in f:
                if line[0:jj]==reserve:
                
                   for i in range(linerid7+1,len(line)):
                        
                        if line[i].isdigit()==True:
                            way_number=i
                        else:
                            break
                   way_number=line[linerid7+1:way_number+1]
                   break
                
                
                
            
            f.close()
            rri=0
            f=open('service.txt','r')
            ff=open('service1.txt','w')
            for line in f:
                rri+=1
                if int(rri)==int(way_number):
                    line=line.replace(line[2:],'None'+'\n')
                    
                ff.write(line)
            ff.close()
            f.close()
            f=open('service.txt','w')
            ff=open('service1.txt','r')
            for line in ff:
                            f.write(line)
            f.close()
            ff.close()
            os.remove('service1.txt')
            f=open('tickets.txt','r')
            ff=open('tickets1.txt','w')
            for line in f: #тут изменяла
                    if line[0:jj]==reserve:
                        line=line.replace(line,'')
                    ff.write(line)
            f.close()
            ff.close()
            f=open('tickets.txt','w')
            ff=open('tickets1.txt','r')
            for line in ff:
                    f.write(line)
            ff.close()
            f.close()
            os.remove('tickets1.txt')       
            
            
            
                
            print('Готово!')
        
        if int(right_now_month)==int(way_month):
            if int(right_now_day)<int(way_day):
                print('Цена вашего билета:'+str(way_price))
                print('Происходит возврат средств...')
                print('На ваш счет были зачислены '+str(way_price))
                f=open('tickets.txt','r')
                for line in f:
                  if line[0:jj]==reserve:
                    for i in range(len(line)-1):
                        if line[i]=='|':
                            liner3+=1
                            if liner3==13:
                                linerid7=i
                                break
                    break
                f.close()
                f=open('tickets.txt','r')
                for line in f:
                    if line[0:jj]==reserve:

                       for i in range(linerid7+1,len(line)):

                            if line[i].isdigit()==True:
                                way_number=i
                            else:
                                break
                       way_number=line[linerid7+1:way_number+1]
                       break




                f.close()
                rri=0
                f=open('service.txt','r')
                ff=open('service1.txt','w')
                for line in f:
                    rri+=1
                    if int(rri)==int(way_number):
                        line=line.replace(line[2:],'None'+'\n')

                    ff.write(line)
                ff.close()
                f.close()
                f=open('service.txt','w')
                ff=open('service1.txt','r')
                for line in ff:
                                f.write(line)
                f.close()
                ff.close()
                os.remove('service1.txt')
                f=open('tickets.txt','r')
                ff=open('tickets1.txt','w')
                for line in f: #тут изменяла
                    if line[0:jj]==reserve:
                        line=line.replace(line,'')
                    ff.write(line)
                f.close()
                ff.close()
                f=open('tickets.txt','w')
                ff=open('tickets1.txt','r')
                for line in ff:
                    f.write(line)
                ff.close()
                f.close()
                os.remove('tickets1.txt')
                
                    
            if int(right_now_day)==int(way_day):
                
                print('Цена вашего билета: '+str(way_price))
                way_price=int(way_price)
                ww=way_price*65/100
                print('Возврат будет в размере: '+str(ww))
                
                
                print('Ожидайте...')
                f=open('tickets.txt','r')
                for line in f:
                  if line[0:jj]==reserve:
                    for i in range(len(line)-1):
                        if line[i]=='|':
                            liner3+=1
                            if liner3==13:
                                linerid7=i
                                break
                    break
                f.close()
                
                f=open('tickets.txt','r')
                for line in f:
                    if line[0:jj]==reserve:

                       for i in range(linerid7+1,len(line)):

                            if line[i].isdigit()==True:
                                way_number=i
                            else:
                                break
                       way_number=line[linerid7+1:way_number+1]
                       break




                f.close()
                rri=0
                f=open('service.txt','r')
                ff=open('service1.txt','w')
                for line in f:
                    rri+=1
                    if int(rri)==int(way_number):
                        line=line.replace(line[2:],'None'+'\n')

                    ff.write(line)
                ff.close()
                f.close()
                f=open('service.txt','w')
                ff=open('service1.txt','r')
                for line in ff:
                                f.write(line)
                f.close()
                ff.close()
                os.remove('service1.txt')
                f=open('tickets.txt','r')
                ff=open('tickets1.txt','w')
                for line in f: #тут изменяла
                    if line[0:jj]==reserve:
                        line=line.replace(line,'')
                    ff.write(line)
                f.close()
                ff.close()
                f=open('tickets.txt','w')
                ff=open('tickets1.txt','r')
                for line in ff:
                    f.write(line)
                ff.close()
                f.close()
                os.remove('tickets1.txt')
                print('На ваш счет были зачислены '+str(ww))
            
            if  int(right_now_day)>int(way_day):
                print('Невозможно сдать билет.')
        if int(right_now_month)>int(way_month):
            print('Невозможно сдать билет.')
    else:
        print('Данный билет не найден.')
    
    
    
else:
    print('Вы ввели что-то не то.')
# Out:
# Приветствуем в нашей авиакомпании "Mdashan"! Хотите купить билет или сдать?("buy","pass")buy
# Список рейсов:
# 000000 ['MOSCOW', '06:15', 'RIGA', '14:27']
# 000001 ['RIGA', '17:02', 'BERLIN', '20:20']
# 000010 ['MOSCOW', '15:38', 'BERLIN', '03:05']
# 000011 ['MOSCOW', '15:30', 'HELSINKI', '19:41']
# 000100 ['HELSINKI', '10:11', 'SINGAPUR', '17:54']
# 000101 ['MOSCOW', '03:11', 'BAKU', '06:49']
# 000110 ['BAKU', '08:00', 'ABU-DABI', '12:37']
# 000111 ['ABU-DABI', '14:02', 'SINGAPUR', '16:58']
# 001000 ['SINGAPUR', '17:14', 'TOKIO', '21:41']
# 001001 ['ABU-DABI', '14:02', 'BERLIN', '02:58']
# 001010 ['SINGAPUR', '17:14', 'MOSCOW', '09:41']
# 001011 ['EGYPT', '02:00', 'SINGAPUR', '14:00']
# 001100 ['SAINT-PETERSBURG', '18:14', 'TOKIO', '06:00']
# 001101 ['SAINT-PETERSBURG', '22:02', 'PARIS', '03:58']
# 001110 ['SAINT-PETERSBURG', '11:14', 'BARSELONA', '17:41']
# 001111 ['MOSCOW', '09:02', 'SAINT-PETERSBURG', '11:02']
# ...

# %%
# Out:
# True
